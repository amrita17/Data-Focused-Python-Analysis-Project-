# %%
import requests
from bs4 import BeautifulSoup as bs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from collections import defaultdict

# %% [markdown]
# ## Read Fresh Vegetables data from USDA website into csv and then load into data frame

# %%
url = 'https://www.ers.usda.gov/webdocs/DataFiles/54529/SandU%20Fresh.xlsx?v=43189'
r = requests.get(url)
with open("fresh.csv",'wb') as f:
    f.write(r.content)

# %%
# Load fresh.csv into dataframe
# fresh.csv has 32 sheets for 32 vegetables. Hence loading all the the sheets into one single dataframe
column_names = ['Vegetable','Year','Production','Imports','Supply','Exports','Domestic_Availability','Per_Capita_Availability','Current_Dollars','Constant_2009_Dollars']
fresh_df = pd.DataFrame(columns=column_names)
for i in range(1,31):
    temp_df= pd.read_excel("fresh.csv", sheet_name=i)
    if temp_df.shape[1] == 9: # to remove those sheets which have more than 9 columns
        # Get the vegetable name and insert as the first column of the dataframe
        col1 =temp_df.columns[0]
        beg_pos = 15
        end_pos = col1.find(':')
        veg_name = col1[beg_pos:end_pos]
        veg_name = veg_name.replace(', all uses','')
        veg_name = veg_name.replace('fresh ','')
        temp_df.insert(loc=0, column='Vegetable', value=veg_name) 
        
        # now rename the columns and concatenate the DF
        temp_df.columns = column_names
        fresh_df = pd.concat([fresh_df,temp_df.iloc[4:51]], ignore_index  = True) # only rows between 4 and 51 are relevant

# %%
fresh_df.shape
# Out:
# (965, 10)

# %%
# Write the dataframe data to excel file
writer = pd.ExcelWriter('all_vegetables.xlsx', engine='xlsxwriter')
fresh_df.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
fresh_df.head()
# Out:
#     Vegetable  Year Production Imports Supply         Exports  \
# 0  artichokes  1971       79.2    26.1  105.3              --
# 1  artichokes  1972         71    46.8  117.8              --
# 2  artichokes  1973         60    43.5  103.5              --
# 3  artichokes  1974       70.2    37.8    108              --
# 4  artichokes  1975       73.4    32.4  105.8              --
#
#   Domestic_Availability Per_Capita_Availability Current_Dollars  \
# 0                 105.3                0.507076            9.72
# 1                 117.8                 0.56123            11.6
# 2                 103.5                0.488417            14.5
# 3                   108                0.505017            17.3
# 4                 105.8                0.489876            16.1
#
#   Constant_2009_Dollars
# 0               40.5608
# 1               46.3907
# 2               54.9951
# 3               60.2074
# 4               51.2821

# %% [markdown]
# ### Web scrape the food price index data

# %%
page = requests.get('https://ycharts.com/indicators/agriculture_index_world_bank')
page = page.content
soup = bs(page, 'html.parser')
dataTableBox = soup.find('div', {"id": "dataTableBox"})
col1 = []
col2 = []
# get the data from table into lists
for tr in dataTableBox.find_all('tr')[2:]:
    cols = tr.find_all('td')
    if(len(cols) == 0 ): # for empty div comming in between
        continue
#     print(datetime.strptime(cols[0].text, '%m. %d, %y'))
    col1.append(cols[0].text)
    col2.append(float(cols[1].text.strip()))

# Create dataframe from the lists of data
pd1_input_list = {'Month':col1,'Price_Index':col2}
df1 = pd.DataFrame(pd1_input_list)
# Get the year in separate column and get the average price_indices foe each year
df1['Year'] = df1.Month.str.slice(-4)
# Write the dataframe data to excel file
writer = pd.ExcelWriter('monthly_price_index.xlsx', engine='xlsxwriter')
df1.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
df1
# Out:
#              Month  Price_Index  Year
# 0    Feb. 28, 2018        89.16  2018
# 1    Jan. 31, 2018        87.52  2018
# 2    Dec. 31, 2017        85.38  2017
# 3    Nov. 30, 2017        85.96  2017
# 4    Oct. 31, 2017        85.59  2017
# 5   Sept. 30, 2017        86.33  2017
# 6    Aug. 31, 2017        85.30  2017
# 7    July 31, 2017        87.57  2017
# 8    June 30, 2017        87.05  2017
# 9     May 31, 2017        88.35  2017
# 10  April 30, 2017        86.90  2017
# 11  March 31, 2017        88.26  2017
# 12   Feb. 28, 2017        90.08  2017
# 13   Jan. 31, 2017        90.15  2017
# 14   Dec. 31, 2016        87.92  2016
# 15   Nov. 30, 2016        88.44  2016
# 16   Oct. 31, 2016        87.71  2016
# 17  Sept. 30, 2016        88.87  2016
# 18   Aug. 31, 2016        89.36  2016
# 19   July 31, 2016        90.74  2016
# 20   June 30, 2016        92.98  2016
# 21    May 31, 2016        90.09  2016
# 22  April 30, 2016        87.08  2016
# 23  March 31, 2016        84.50  2016
# 24   Feb. 29, 2016        82.51  2016
# 25   Jan. 31, 2016        82.01  2016
# 26   Dec. 31, 2015        85.39  2015
# 27   Nov. 30, 2015        85.65  2015
# 28   Oct. 31, 2015        86.78  2015
# 29  Sept. 30, 2015        85.84  2015
# 30   Aug. 31, 2015        87.52  2015
# 31   July 31, 2015        90.80  2015
# 32   June 30, 2015        90.16  2015
# 33    May 31, 2015        90.10  2015
# 34  April 30, 2015        90.45  2015
# 35  March 31, 2015        90.75  2015
# 36   Feb. 28, 2015        93.36  2015
# 37   Jan. 31, 2015        94.67  2015
# 38   Dec. 31, 2014        96.81  2014
# 39   Nov. 30, 2014        98.28  2014
# 40   Oct. 31, 2014        98.01  2014
# 41  Sept. 30, 2014        98.42  2014
# 42   Aug. 31, 2014       102.07  2014
# 43   July 31, 2014       103.16  2014
# 44   June 30, 2014       105.16  2014
# 45    May 31, 2014       107.18  2014
# 46  April 30, 2014       107.21  2014
# 47  March 31, 2014       108.00  2014
# 48   Feb. 28, 2014       106.10  2014

# %% [markdown]
# ### Download the data from url into csv

# %% [markdown]
# ### Getting Data from API:

# %%
import requests
import sys
import json

key = 'GlanxFCOEPxiiEXJK37dPGQjnfM0wFfrZf2uuWti'
url = 'https://api.nal.usda.gov/ndb/nutrients/?format=json&api_key=GlanxFCOEPxiiEXJK37dPGQjnfM0wFfrZf2uuWti&nutrients=208&nutrients=203&nutrients=204&nutrients=205&nutrients=291&nutrients=269&nutrients=211&nutrients=212&fg=1100'
response = requests.get(url)
x = response.json()
# df3 = pd.io.json.json_normalize(x['report']['foods'])
# df3.columns = df3.columns.map(lambda x: x.split(".")[-1])

# grab the nutrient information and vegetable name information from nested dict structure from json
my_data = x['report']['foods']
nut_info = [nut for veggie in my_data for nut in veggie['nutrients']] # list of nutrient info
veg = [veggie['name'] for veggie in my_data for nut in veggie['nutrients']] # list of vegetable names - each name is repeated 8 times fro 8 nutrients

#Create dictionary to get just the nutrient value in 'gm' 
gm_dict = {}
gm_dict = defaultdict(list)
for item in nut_info:
    gm_dict['gm'].append(item['gm'])
# create the data frame of the nutrient info - each nutrient values is in each row
nutrients_df_raw = pd.DataFrame(gm_dict)

# get the nutrients in a column format by reshaping the dataframe - total 8 nutrients, so 8 columns are created

nutrients_df_raw = pd.DataFrame(np.reshape(nutrients_df_raw.values,(150,8)), 
                    columns=['Glucose','Fructose','Protein','Sugars','fat','Carbohydrate' , 'Energy', 'Fiber'])
nutrients_df_raw['Veg_full_name'] = veg[0::8] # since each name is repeated 8 times, so grab every eighth name

# %%
nutrients_df_raw
# Out:
#     Glucose Fructose Protein Sugars    fat Carbohydrate Energy Fiber  \
# 0      0.08     0.12    3.99    0.2   0.69          2.1     23   1.9
# 1      0.24     0.02    2.89   0.99   0.34        11.39     51   5.7
# 2      0.24     0.02    2.89   0.99   0.34        11.95     53   5.7
# 3      0.42     0.79     2.4    1.3   0.22         4.11     22     2
# 4      0.42     0.79     2.4    1.3   0.22         4.11     22     2
# 5      0.65        1     2.2   1.88   0.12         3.88     20   2.1
# 6      0.29     0.33    1.12   0.78   0.46         4.32     22   1.9
# 7      0.63     0.62    1.05   1.44   0.41         4.19     21   1.9
# 8      0.83     1.36    1.98    2.6   0.41         6.98     33   3.4
# 9      0.92     1.04    1.79   2.21   0.21         7.54     33   2.6
# 10     1.44     1.45    2.31   3.22    0.5         6.41     33   3.4
# 11     1.51     1.39    1.83   3.26   0.22         6.97     31   2.7
# 12     0.28      0.2    0.73   6.53   0.09         7.14     30   1.2
# 13     0.23     0.24    3.83   0.62   0.52         3.12     25   2.8
# 14      0.1     0.17    3.17   0.38   0.49         2.85     22   2.7
# 15     0.49     0.74    2.38   1.39   0.41         7.18     35   3.3
# 16     0.49     0.74    2.38   1.39   0.41         7.18     35   3.3
# 17     0.75     0.83    2.81   1.35   0.29         4.78     26     3
# 18     0.49     0.68    2.82    1.7   0.37         6.64     34   2.6
# 19     0.81     0.93    3.38    2.2    0.3         8.95     43   3.8
# 20     1.62     1.16    1.27   2.79   0.06         5.51     23   1.9
# 21     1.62     1.16    1.27   2.79   0.06         5.51     23   1.9
# 22     1.67     1.45    1.28    3.2    0.1          5.8     25   2.5
# 23     1.42      1.2    1.51   3.32   0.09         6.94     29   2.6
# 24     1.42      1.2    1.51   3.32   0.09         6.94     29   2.6
# 25     1.74     1.48    1.43   3.83   0.16         7.37     31   2.1
# 26     1.04        1    0.64   4.76   0.13         8.24     35   2.9
# 27     0.28     0.26    0.59   2.46   0.14         5.36     23   1.8
# 28      0.4     0.36    0.76   3.45   0.18         8.22     35     3
# 29      0.4     0.36    0.76   3.45   0.18         8.22     35     3
# ..      ...      ...     ...    ...    ...          ...    ...   ...
# 120    0.52     0.55     0.5   1.07    0.3         2.41     12     1
# 121    9.17     8.81    0.58  18.27   0.41        21.15     91     1
# 122    0.76     0.56    6.08   1.79  14.76        27.81    268   3.3
# 123    0.19        0    2.13   0.27   9.05        27.29    192     2
# 124    0.16        0    1.93   0.28   8.71         24.8    178   2.3
# 125    0.44     0.34     2.5   1.18   0.13        21.15     93   2.2
# 126    0.44     0.34     2.5   1.18   0.13        21.15     93   2.2
# 127    0.34     0.29    1.87   0.91    0.1        20.13     87   1.8
# 128    0.33     0.28    1.71   0.89    0.1        20.01     86   1.8
# 129    0.31     0.26    2.05   0.82   0.09        17.49     77   2.1
# 130    0.18        0    2.75   0.37   5.48        25.55    158     2
# 131     0.1        0    2.24    0.2   4.66        24.81    147   1.9
# 132     0.1        0    2.24    0.2   4.66        24.81    147   1.9
# 133    0.11        0    2.66   0.28   5.22        28.71    168   2.6
# 134    0.07        0    2.34   0.21   4.99        23.96    146     2
# 135    0.12        0    2.51   0.29   5.13         27.5    161   2.3
# 136    0.12        0    2.16    0.2   6.24        25.59    163   2.3
# 137     0.1        0     2.9   0.31   6.76        31.66    194   2.8
# 138     0.1        0    2.19    0.2   3.39        23.51    130   1.9
# 139     0.1        0    2.57   0.25   3.76        26.98    148   2.6
# 140    0.26        0    2.65   0.27  11.59        28.51    219   3.2
# 141    0.64     0.52       3   1.49  12.52        35.11    265   3.2
# 142    0.61     0.45    3.24   1.16   10.3        33.99    242   3.6
# 143    0.54     0.36    1.75   0.91   0.08        19.16     84   1.8
# 144    0.89     0.98    8.34   3.36   0.41        81.17    354   6.6
# 145    0.92     1.01    8.22   3.47   0.54        85.51    372   7.1
# 146    0.11     0.12    1.77   1.61   5.13        10.87     97   0.8
# 147    0.16     0.18    2.13   1.74    4.8        16.13    116   1.3
# 148    0.31     0.25    1.91   1.48   0.57        17.57     83   1.5
# 149    0.29     0.24    1.86   1.43   4.22        16.81    113   1.5
#
#                                          Veg_full_name  Vegetable
# 0                         Alfalfa seeds, sprouted, raw
# 1    Artichokes, (globe or french), cooked, boiled,...
# 2    Artichokes, (globe or french), cooked, boiled,...
# 3                   Asparagus, cooked, boiled, drained
# 4        Asparagus, cooked, boiled, drained, with salt
# 5                                       Asparagus, raw  asparagus
# 6    Beans, snap, green, canned, no salt added, dra...
# 7    Beans, snap, green, canned, regular pack, drai...
# 8    Beans, snap, green, frozen, all styles, microw...
# 9    Beans, snap, green, frozen, all styles, unprep...
# 10                      Beans, snap, green, microwaved
# 11                             Beans, snap, green, raw
# 12     Beets, canned, regular pack, solids and liquids
# 13                               Broccoli raab, cooked
# 14                                  Broccoli raab, raw
# 15        Broccoli, cooked, boiled, drained, with salt
# 16     Broccoli, cooked, boiled, drained, without salt
# 17               Broccoli, frozen, chopped, unprepared
# 18                                       Broccoli, raw   broccoli
# 19                               Brussels sprouts, raw
# 20   Cabbage, common, cooked, boiled, drained, with...
# 21      Cabbage, cooked, boiled, drained, without salt
# 22                                        Cabbage, raw
# 23    Cabbage, red, cooked, boiled, drained, with salt
# 24   Cabbage, red, cooked, boiled, drained, without...
# 25                                   Cabbage, red, raw
# 26                                  Carrots, baby, raw
# 27   Carrots, canned, no salt added, solids and liq...
# 28         Carrots, cooked, boiled, drained, with salt
# 29      Carrots, cooked, boiled, drained, without salt
# ..                                                 ...        ...
# 120            Pickles, cucumber, dill, reduced sodium
# 121  Pickles, cucumber, sweet (includes bread and b...
# 122                                    Potato pancakes
# 123                  Potato puffs, frozen, oven-heated
# 124                   Potato puffs, frozen, unprepared
# 125         Potatoes, baked, flesh and skin, with salt
# 126      Potatoes, baked, flesh and skin, without salt
# 127  Potatoes, boiled, cooked in skin, flesh, witho...
# 128  Potatoes, boiled, cooked without skin, flesh, ...
# 129                      Potatoes, flesh and skin, raw
# 130  Potatoes, french fried, all types, salt added ...
# 131  Potatoes, french fried, all types, salt added ...
# 132  Potatoes, french fried, all types, salt not ad...
# 133  Potatoes, french fried, all types, salt not ad...
# 134  Potatoes, french fried, crinkle or regular cut...
# 135  Potatoes, french fried, crinkle or regular cut...
# 136  Potatoes, french fried, shoestring, salt added...
# 137  Potatoes, french fried, shoestring, salt added...
# 138  Potatoes, french fried, steak fries, salt adde...
# 139  Potatoes, french fried, steak fries, salt adde...
# 140  Potatoes, hash brown, frozen, plain, prepared,...
# 141                Potatoes, hash brown, home-prepared
# 142  Potatoes, hash brown, refrigerated, prepared, ...
# 143     Potatoes, hash brown, refrigerated, unprepared
# 144  Potatoes, mashed, dehydrated, flakes without m...
# 145  Potatoes, mashed, dehydrated, granules without...
# 146  Potatoes, mashed, dehydrated, prepared from fl...
# 147  Potatoes, mashed, dehydrated, prepared from gr...
# 148  Potatoes, mashed, home-prepared, whole milk added
# 149  Potatoes, mashed, home-prepared, whole milk an...
#
# [150 rows x 10 columns]

# %% [markdown]
# ### Join Fresh DF and Price index dataframe

# %%
pi_by_year = df1.groupby('Year', as_index=False)['Price_Index'].mean() 
pi_by_year['Year'] = pi_by_year['Year'].astype(int) # convert year to int type
# merge fresh_df and pi_by_year on Year column values
final_df = pd.merge(fresh_df, pi_by_year, on="Year",how='left')

# %%
final_df
# Out:
#       Vegetable  Year Production  Imports   Supply         Exports  \
# 0    artichokes  1971       79.2     26.1    105.3              --
# 1    artichokes  1972         71     46.8    117.8              --
# 2    artichokes  1973         60     43.5    103.5              --
# 3    artichokes  1974       70.2     37.8      108              --
# 4    artichokes  1975       73.4     32.4    105.8              --
# 5    artichokes  1976       80.6     42.9    123.5             4.6
# 6    artichokes  1977       71.3     34.5    105.8             3.8
# 7    artichokes  1978       52.5     58.5      111             3.3
# 8    artichokes  1979       87.3       54    141.3               4
# 9    artichokes  1980       79.2     58.5    137.7               4
# 10   artichokes  1981      111.6     65.4      177             5.1
# 11   artichokes  1982      116.3     79.2    195.5             4.4
# 0                   105.3                0.507076            9.72
# 1                   117.8                 0.56123            11.6
# 2                   103.5                0.488417            14.5
# 3                     108                0.505017            17.3
# 4                   105.8                0.489876            16.1
# 5                   118.9                0.545325            14.4
# 6                     102                0.463133            19.3
# 7                   107.7                 0.48386              27
# 8                   137.3                0.610073            27.7
# 9                   133.7                0.587109            34.7
# 10                  171.9                0.747502              32
# 11                  191.1                 0.82304            32.1
# 12                  172.1                0.734506           38.25
# 13                  225.6                0.954525           30.65
# 14                  243.9                 1.02279            28.6
# 15                  225.1                0.935379           34.45
# 16                  241.1                0.992982            30.2
# 17                  224.1                0.914615           29.35
# 18                241.002                0.974368            26.5
# 19                211.566                0.845815            29.5
# 20                209.602                0.826856           29.65
# 21                225.776                0.878869            39.4
# 22                224.817                0.863834            50.8
# 23                333.588                  1.2663            56.4
# 24                246.508                0.924784            75.7
# 25                266.812                0.989414            73.5
# 26                275.562                 1.00971            79.5
# 27                325.793                 1.17992            70.6
# 28                368.898                 1.32082              67
# 29                350.648                 1.24174            60.3
# ..                    ...                     ...             ...
# 935                4124.5                 16.8332            27.1
# 936               4166.08                 16.8434            33.2
# 937                3882.8                  15.523            27.4
# 938               3894.01                 15.3614            31.7
# 939               3967.99                  15.446            35.8
# 940               4242.87                 16.3027            31.7
# 941               4270.92                 16.2124            27.4
# 942               4489.48                 16.8425            25.5
# 943                4693.1                 17.4033            28.1
# 944               4720.01                  17.295            31.7
# 945               5107.29                  18.497            35.2
# 946                5325.6                  19.068            25.8
# 947               5361.03                 18.9849            30.7
# 948                5478.8                 19.2031              30
# 949               5851.83                 20.3115            31.6
# 950               5645.32                 19.4117            37.5
# 951               5854.53                 19.9498            37.4
# 952               5968.51                 20.1512            41.6
# 953               5911.23                 19.7703            43.7
# 954               5800.98                 19.2083            34.8
# 955                5642.9                 18.5136            45.3
# 956               6022.53                 19.5893            40.4
# 957               6366.14                 20.5514            48.2
# 958               6542.69                  20.961            36.1
# 959               6532.01                 20.7735            30.5
# 960               6402.03                  20.213            44.6
# 961               6573.42                 20.5945            41.5
# 962               6596.79                 20.5423            46.3
# 963               6582.36                 20.3568            42.5
# 964               6600.81                 20.2749            37.3
#
#     Constant_2009_Dollars  Price_Index
# 0                 40.5608          NaN
# 1                 46.3907          NaN
# 2                 54.9951          NaN
# 3                 60.2074          NaN
# 4                 51.2821          NaN
# 5                 43.4796          NaN
# 6                 54.8716          NaN
# 7                 71.7265          NaN
# 8                 67.9755          NaN
# 9                 78.1092          NaN
# 10                65.8816          NaN
# 11                62.2262          NaN
# 12                71.3313          NaN
# 13                55.2004          NaN
# 14                 49.911          NaN
# 15                58.9312          NaN
# 16                50.3762          NaN
# 17                47.3021          NaN
# 18                41.1108          NaN
# 19                44.1319          NaN
# 20                42.9281          NaN
# 21                55.7726          NaN
# 22                70.2385          NaN
# 23                76.3555          NaN
# 24                 100.39          NaN
# 25                95.7243          NaN
# 26                101.798          NaN
# 27                89.4305          NaN
# 28                83.6757          NaN
# 29                73.6345          NaN
# ..                    ...          ...
# 935               43.6759          NaN
# 936               51.5048          NaN
# 937               40.9904          NaN
# 938               45.8961          NaN
# 939               50.6766          NaN
# 940               43.8299          NaN
# 941               37.0947          NaN
# 942               33.8169          NaN
# 943               36.5966          NaN
# 944               40.5911          NaN
# 945               44.5886          NaN
# 946               32.2214          NaN
# 947               37.4889          NaN
# 948               35.8141          NaN
# 949               37.1529          NaN
# 950               43.2257          NaN
# 951               41.9602          NaN
# 952               45.2218          NaN
# 953               46.0883          NaN
# 954               35.7528          NaN
# 955               45.6488          NaN
# 956                  40.4          NaN
# 957               47.6233          NaN
# 958                34.981          NaN
# 959               29.0024          NaN
# 960               41.7112          NaN
# 961                38.185   102.763636
# 962               42.1779    89.289167
# 963               38.1363    87.684167
# 964               32.9688    87.243333
#
# [965 rows x 11 columns]

# %% [markdown]
# ### Find the common vegetables in Nutrient DF and Final DF and then merge the two DF

# %%
raw_names_nut = [ item for item in nutrients_df_raw['Veg_full_name'] if item.find('raw') > 0]
# find nutrient information for all the vegetables that are present in the fresh vegetables DF
nutrients_df_raw['Vegetable'] = ''
for veg in final_df['Vegetable'].unique():
    veggie = veg + ', raw'
    raw_veggie = [rnn for rnn in raw_names_nut if veggie.lower() in rnn.lower()]
    if len(raw_veggie) > 0:
        true_idx = nutrients_df_raw['Veg_full_name'] == raw_veggie[0]
        nutrients_df_raw['Vegetable'][true_idx] = veg
# Merge nutrients dataframe and Final DF
final_df = pd.merge(final_df, nutrients_df_raw, on="Vegetable", how = 'left')

# Write the dataframe data to excel file
writer = pd.ExcelWriter('final_data.xlsx', engine='xlsxwriter')
final_df.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
final_df
# Out:
#       Vegetable  Year Production  Imports   Supply         Exports  \
# 0    artichokes  1971       79.2     26.1    105.3              --
# 1    artichokes  1972         71     46.8    117.8              --
# 2    artichokes  1973         60     43.5    103.5              --
# 3    artichokes  1974       70.2     37.8      108              --
# 4    artichokes  1975       73.4     32.4    105.8              --
# 5    artichokes  1976       80.6     42.9    123.5             4.6
# 6    artichokes  1977       71.3     34.5    105.8             3.8
# 7    artichokes  1978       52.5     58.5      111             3.3
# 8    artichokes  1979       87.3       54    141.3               4
# 9    artichokes  1980       79.2     58.5    137.7               4
# 10   artichokes  1981      111.6     65.4      177             5.1
# 11   artichokes  1982      116.3     79.2    195.5             4.4
# 12   artichokes  1983       89.2     86.1    175.3             3.2
# 13   artichokes  1984      109.9      120    229.9             4.3
# 14   artichokes  1985      133.8    116.1    249.9               6
# 15   artichokes  1986      105.2    125.4    230.6             5.5
# 16   artichokes  1987      121.7    124.8    246.5             5.4
# 17   artichokes  1988      124.6    106.2    230.8             6.7
# 18   artichokes  1989      129.6  117.702  247.302             6.3
# 19   artichokes  1990      111.4  106.666  218.066             6.5
# 20   artichokes  1991      120.6  94.7021  215.302             5.7
# 14                  243.9                 1.02279            28.6
# 15                  225.1                0.935379           34.45
# 16                  241.1                0.992982            30.2
# 17                  224.1                0.914615           29.35
# 18                241.002                0.974368            26.5
# 19                211.566                0.845815            29.5
# 20                209.602                0.826856           29.65
# 21                225.776                0.878869            39.4
# 22                224.817                0.863834            50.8
# 23                333.588                  1.2663            56.4
# 24                246.508                0.924784            75.7
# 25                266.812                0.989414            73.5
# 26                275.562                 1.00971            79.5
# 27                325.793                 1.17992            70.6
# 28                368.898                 1.32082              67
# 29                350.648                 1.24174            60.3
# ..                    ...                     ...             ...
# 935                4124.5                 16.8332            27.1
# 936               4166.08                 16.8434            33.2
# 937                3882.8                  15.523            27.4
# 938               3894.01                 15.3614            31.7
# 939               3967.99                  15.446            35.8
# 940               4242.87                 16.3027            31.7
# 941               4270.92                 16.2124            27.4
# 942               4489.48                 16.8425            25.5
# 943                4693.1                 17.4033            28.1
# 944               4720.01                  17.295            31.7
# 945               5107.29                  18.497            35.2
# 946                5325.6                  19.068            25.8
# 947               5361.03                 18.9849            30.7
# 948                5478.8                 19.2031              30
# 949               5851.83                 20.3115            31.6
# 950               5645.32                 19.4117            37.5
# 951               5854.53                 19.9498            37.4
# 952               5968.51                 20.1512            41.6
# 953               5911.23                 19.7703            43.7
# 954               5800.98                 19.2083            34.8
# 955                5642.9                 18.5136            45.3
# 956               6022.53                 19.5893            40.4
# 957               6366.14                 20.5514            48.2
# 958               6542.69                  20.961            36.1
# 959               6532.01                 20.7735            30.5
# 960               6402.03                  20.213            44.6
# 961               6573.42                 20.5945            41.5
# 962               6596.79                 20.5423            46.3
# 963               6582.36                 20.3568            42.5
# 964               6600.81                 20.2749            37.3
#
#     Constant_2009_Dollars  Price_Index Glucose Fructose Protein Sugars  fat  \
# 0                 40.5608          NaN     NaN      NaN     NaN    NaN  NaN
# 1                 46.3907          NaN     NaN      NaN     NaN    NaN  NaN
# 2                 54.9951          NaN     NaN      NaN     NaN    NaN  NaN
# 3                 60.2074          NaN     NaN      NaN     NaN    NaN  NaN
# 4                 51.2821          NaN     NaN      NaN     NaN    NaN  NaN
# 5                 43.4796          NaN     NaN      NaN     NaN    NaN  NaN
# 6                 54.8716          NaN     NaN      NaN     NaN    NaN  NaN
# 7                 71.7265          NaN     NaN      NaN     NaN    NaN  NaN
# 8                 67.9755          NaN     NaN      NaN     NaN    NaN  NaN
# 9                 78.1092          NaN     NaN      NaN     NaN    NaN  NaN
# 10                65.8816          NaN     NaN      NaN     NaN    NaN  NaN
# 11                62.2262          NaN     NaN      NaN     NaN    NaN  NaN
# 12                71.3313          NaN     NaN      NaN     NaN    NaN  NaN
# 13                55.2004          NaN     NaN      NaN     NaN    NaN  NaN
# 14                 49.911          NaN     NaN      NaN     NaN    NaN  NaN
# 15                58.9312          NaN     NaN      NaN     NaN    NaN  NaN
# 16                50.3762          NaN     NaN      NaN     NaN    NaN  NaN
# 1            NaN    NaN   NaN           NaN
# 2            NaN    NaN   NaN           NaN
# 3            NaN    NaN   NaN           NaN
# 4            NaN    NaN   NaN           NaN
# 5            NaN    NaN   NaN           NaN
# 6            NaN    NaN   NaN           NaN
# 7            NaN    NaN   NaN           NaN
# 8            NaN    NaN   NaN           NaN
# 9            NaN    NaN   NaN           NaN
# 10           NaN    NaN   NaN           NaN
# 11           NaN    NaN   NaN           NaN
# 12           NaN    NaN   NaN           NaN
# 13           NaN    NaN   NaN           NaN
# 14           NaN    NaN   NaN           NaN
# 15           NaN    NaN   NaN           NaN
# 16           NaN    NaN   NaN           NaN
# 17           NaN    NaN   NaN           NaN
# 18           NaN    NaN   NaN           NaN
# 19           NaN    NaN   NaN           NaN
# 20           NaN    NaN   NaN           NaN
# 21           NaN    NaN   NaN           NaN
# 22           NaN    NaN   NaN           NaN
# 23           NaN    NaN   NaN           NaN
# 24           NaN    NaN   NaN           NaN
# 25           NaN    NaN   NaN           NaN
# 26           NaN    NaN   NaN           NaN
# 27           NaN    NaN   NaN           NaN
# 28           NaN    NaN   NaN           NaN
# 29           NaN    NaN   NaN           NaN
# ..           ...    ...   ...           ...
# 935          NaN    NaN   NaN           NaN
# 936          NaN    NaN   NaN           NaN
# 937          NaN    NaN   NaN           NaN
# 938          NaN    NaN   NaN           NaN
# 939          NaN    NaN   NaN           NaN
# 940          NaN    NaN   NaN           NaN
# 941          NaN    NaN   NaN           NaN
# 942          NaN    NaN   NaN           NaN
# 943          NaN    NaN   NaN           NaN
# 944          NaN    NaN   NaN           NaN
# 945          NaN    NaN   NaN           NaN
# 946          NaN    NaN   NaN           NaN
# 947          NaN    NaN   NaN           NaN
# 948          NaN    NaN   NaN           NaN
# 949          NaN    NaN   NaN           NaN
# 950          NaN    NaN   NaN           NaN
# 951          NaN    NaN   NaN           NaN
# 952          NaN    NaN   NaN           NaN
# 953          NaN    NaN   NaN           NaN
# 954          NaN    NaN   NaN           NaN
# 955          NaN    NaN   NaN           NaN
# 956          NaN    NaN   NaN           NaN
# 957          NaN    NaN   NaN           NaN
# 958          NaN    NaN   NaN           NaN
# 959          NaN    NaN   NaN           NaN
# 960          NaN    NaN   NaN           NaN
# 961          NaN    NaN   NaN           NaN
# 962          NaN    NaN   NaN           NaN
# 963          NaN    NaN   NaN           NaN
# 964          NaN    NaN   NaN           NaN
#
# [965 rows x 20 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28 entries, 0 to 27
# Data columns (total 20 columns):
# Vegetable                  28 non-null object
# Year                       28 non-null object
# Production                 28 non-null object
# Imports                    28 non-null object
# Supply                     28 non-null object
# Exports                    28 non-null object
# Domestic_Availability      28 non-null object
# Per_Capita_Availability    28 non-null object
# Current_Dollars            28 non-null object
# Constant_2009_Dollars      28 non-null object
# Price_Index                28 non-null float64
# Glucose                    28 non-null object
# Fructose                   28 non-null object
# Protein                    28 non-null object
# Sugars                     28 non-null object
# fat                        28 non-null object
# Carbohydrate               28 non-null object
# Energy                     28 non-null object
# Fiber                      28 non-null object
# Veg_full_name              28 non-null object
# dtypes: float64(1), object(19)
# memory usage: 4.6+ KB

# %%
imports = final_df.groupby('Vegetable')['Imports'].sum() 
imports.plot.bar()
plt.title('Total Imports per vegetable')
plt.xticks(rotation=20)
plt.ylabel('Imports')
plt.show()

# Make note of units when displaying in charts
# Currently using only 4 years of data. Can we increase more data.
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in f(self, **kwargs)
#    1243                     return self._cython_agg_general(
# -> 1244                         alias, alt=npfunc, **kwargs)
#    1245                 except AssertionError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     926         if len(output) == 0:
# --> 927             raise DataError('No numeric types to aggregate')
#     928
#
# DataError: No numeric types to aggregate
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count)
#     336         dtype_sum = np.float64
# --> 337     the_sum = values.sum(axis, dtype=dtype_sum)
#     338     the_sum = _maybe_null_out(the_sum, axis, mask, min_count=min_count)
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# TypeError: must be str, not float
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3134             try:
# -> 3135                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    3136             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     944         if len(output) == 0:
# --> 945             return self._python_apply_general(f)
#     946
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _python_apply_general(self, f)
#     808         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 809                                                    self.axis)
#     810
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in apply(self, f, data, axis)
#    1968             group_axes = _get_axes(group)
# -> 1969             res = f(group)
#    1970             if not _is_indexed_like(res, group_axes):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in <lambda>(x)
#     932         func = self._is_builtin_func(func)
# --> 933         f = lambda x: func(x, *args, **kwargs)
#     934
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in <lambda>(x)
#    1248                     result = self.aggregate(
# -> 1249                         lambda x: npfunc(x, axis=self.axis))
#    1250                     if _convert:
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims)
#    1879         else:
# -> 1880             return sum(axis=axis, dtype=dtype, out=out, **kwargs)
#    1881     return _methods._sum(a, axis=axis, dtype=dtype,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    7294         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 7295                             numeric_only=numeric_only, min_count=min_count)
#    7296
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2576             with np.errstate(all='ignore'):
# -> 2577                 return op(delegate, skipna=skipna, **kwds)
#    2578
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     130                 try:
# --> 131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132                 except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count)
#     336         dtype_sum = np.float64
# --> 337     the_sum = values.sum(axis, dtype=dtype_sum)
#     338     the_sum = _maybe_null_out(the_sum, axis, mask, min_count=min_count)
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# TypeError: must be str, not float
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count)
#     336         dtype_sum = np.float64
# --> 337     the_sum = values.sum(axis, dtype=dtype_sum)
#     338     the_sum = _maybe_null_out(the_sum, axis, mask, min_count=min_count)
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# TypeError: must be str, not float
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-199-4e1d1643c18e> in <module>()
# ----> 1 imports = final_df.groupby('Vegetable')['Imports'].sum()
#       2 imports.plot.bar()
#       3 plt.title('Total Imports per vegetable')
#       4 plt.xticks(rotation=20)
#       5 plt.ylabel('Imports')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in f(self, **kwargs)
#    1247                 except Exception:
#    1248                     result = self.aggregate(
# -> 1249                         lambda x: npfunc(x, axis=self.axis))
#    1250                     if _convert:
#    1251                         result = result._convert(datetime=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3135                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    3136             except Exception:
# -> 3137                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#    3138
#    3139             index = Index(sorted(result), name=self.grouper.names[0])
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _aggregate_named(self, func, *args, **kwargs)
#    3265         for name, group in self:
#    3266             group.name = name
# -> 3267             output = func(group, *args, **kwargs)
#    3268             if isinstance(output, (Series, Index, np.ndarray)):
#    3269                 raise Exception('Must produce aggregated value')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in <lambda>(x)
#    1247                 except Exception:
#    1248                     result = self.aggregate(
# -> 1249                         lambda x: npfunc(x, axis=self.axis))
#    1250                     if _convert:
#    1251                         result = result._convert(datetime=True)
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims)
#    1878             pass
#    1879         else:
# -> 1880             return sum(axis=axis, dtype=dtype, out=out, **kwargs)
#    1881     return _methods._sum(a, axis=axis, dtype=dtype,
#    1882                          out=out, **kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    7293                                       skipna=skipna, min_count=min_count)
#    7294         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 7295                             numeric_only=numeric_only, min_count=min_count)
#    7296
#    7297     return set_function_name(stat_func, name, cls)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2575                                           'numeric_only.'.format(name))
#    2576             with np.errstate(all='ignore'):
# -> 2577                 return op(delegate, skipna=skipna, **kwds)
#    2578
#    2579         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     129             except Exception:
#     130                 try:
# --> 131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132                 except ValueError as e:
#     133                     # we want to transform an object array
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count)
#     335     elif is_timedelta64_dtype(dtype):
#     336         dtype_sum = np.float64
# --> 337     the_sum = values.sum(axis, dtype=dtype_sum)
#     338     the_sum = _maybe_null_out(the_sum, axis, mask, min_count=min_count)
#     339
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: must be str, not float

# %%
imports
# Out:
# Vegetable
# asparagus      1893.876983
# broccoli       1805.789438
# carrots        1757.103364
# cauliflower     363.023508
# celery          484.941006
# eggplant        603.348508
# kale             40.433333
# Name: Imports, dtype: float64
